# %% [markdown]
# Q1. Generate N = 500 2-dimensional data points that are distributed according to the Gaussian distribution N(m,S), with mean m = [0, 0] T and covariance matrix
#
# >$S = \begin{bmatrix}
# \sigma_1^2 &  \sigma_{12} \\
# \sigma_{12} &  \sigma_2^2 \\
# \end{bmatrix}$
#
# For the following cases,
#
# >$\sigma_1^2 = 0.2, \sigma_2^2 = 2, \sigma_{12} = 0$
#
# >$\sigma_1^2 = 2, \sigma_2^2 = 0.2, \sigma_{12} = 0$
#
# >$\sigma_1^2 = 1, \sigma_2^2 = 1, \sigma_{12} = 0.5$
#
# >$\sigma_1^2 = 0.3, \sigma_2^2 = 2, \sigma_{12} = 0.5$
#
# >$\sigma_1^2 = 0.3, \sigma_2^2 = 2, \sigma_{12} = -0.5$
#
#
# Plot the generated numbers to visualize the distributions.

# %%
import matplotlib.pyplot as plt
import numpy as np

# plot 1
mean = [0,0]
cov = [[0.2, 0], [0, 2]] 
x = [val for val in range(500)]
a = np.random.multivariate_normal(mean, cov, 500)
y = a[:,0]
z = a[:,1]
fig = plt.figure()
ax = fig.add_subplot(111,projection = '3d')
ax.scatter(x,y,z, c='r', marker ='o')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('2D Data Points according to N(m,S), m = [0,0], S = [[0.2, 0], [0, 2]]')
plt.show()

# %%
# plot 2

mean = [0,0]
cov = [[2,0], [0, 0.2]] 
x = [val for val in range(500)]
a = np.random.multivariate_normal(mean, cov, 500)
y = a[:,0]
z = a[:,1]
fig = plt.figure()
ax = fig.add_subplot(111,projection = '3d')
ax.scatter(x,y,z, c='r', marker ='o')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('2D Data Points according to N(m,S), m = [0,0], S = [[2,0], [0, 0.2]] ')
plt.show()

# %%
# plot 3

mean = [0,0]
cov = [[1,0.5], [0.5, 1]] 
x = [val for val in range(500)]
a = np.random.multivariate_normal(mean, cov, 500)
y = a[:,0]
z = a[:,1]
fig = plt.figure()
ax = fig.add_subplot(111,projection = '3d')
ax.scatter(x,y,z, c='r', marker ='o')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('2D Data Points according to N(m,S), m = [0,0], S = [[1,0.5], [0.5, 1]] ')
plt.show()

# %%
# plot 4

mean = [0,0]
cov = [[0.3,0.5], [0.5, 2]] 
x = [val for val in range(500)]
a = np.random.multivariate_normal(mean, cov, 500)
y = a[:,0]
z = a[:,1]
fig = plt.figure()
ax = fig.add_subplot(111,projection = '3d')
ax.scatter(x,y,z, c='r', marker ='o')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('2D Data Points according to N(m,S), m = [0,0], S = [[0.3,0.5], [0.5, 2]]  ')
plt.show()

# %%
# plot 5

mean = [0,0]
cov = [[0.3,-0.5], [-0.5, 2]] 
x = [val for val in range(500)]
a = np.random.multivariate_normal(mean, cov, 500)
y = a[:,0]
z = a[:,1]
fig = plt.figure()
ax = fig.add_subplot(111,projection = '3d')
ax.scatter(x,y,z, c='r', marker ='o')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('2D Data Points according to N(m,S), m = [0,0], S = [[0.3,-0.5], [-0.5, 2]]')
plt.show()
